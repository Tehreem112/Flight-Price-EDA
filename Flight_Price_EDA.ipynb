# %% [markdown]
# # Flight Price Exploratory Data Analysis

# %%
#import basic libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
flight_df = pd.read_csv("C:\\Users\\jc\\Desktop\\python_projects\\Flight_Price_Dataset.csv")
flight_df.head()
# Out:
#               Airline Source                           Source Name  \
# 0  Malaysian Airlines    CXB                   Cox's Bazar Airport
# 1      Cathay Pacific    BZL                       Barisal Airport
# 2     British Airways    ZYL  Osmani International Airport, Sylhet
# 3  Singapore Airlines    RJH        Shah Makhdum Airport, Rajshahi
# 4     British Airways    SPD                       Saidpur Airport
#
#   Destination                                   Destination Name  \
# 0         CCU  Netaji Subhas Chandra Bose International Airpo...
# 1         CGP      Shah Amanat International Airport, Chittagong
# 2         KUL                 Kuala Lumpur International Airport
# 3         DAC      Hazrat Shahjalal International Airport, Dhaka
# 4         YYZ              Toronto Pearson International Airport
#
#   Departure Date & Time Arrival Date & Time  Duration (hrs) Stopovers  \
# 0       17/11/2025 6:25     17/11/2025 7:38        1.219526    Direct
# ...

# %%
flight_df.tail()
# Out:
#                          Airline Source  \
# 56995             Kuwait Airways    JSR
# 56996             Kuwait Airways    CGP
# 56997  Biman Bangladesh Airlines    CXB
# 56998            British Airways    SPD
# 56999                  Air India    DAC
#
#                                          Source Name Destination  \
# 56995                                Jessore Airport         CCU
# 56996  Shah Amanat International Airport, Chittagong         CCU
# 56997                            Cox's Bazar Airport         JSR
# 56998                                Saidpur Airport         YYZ
# 56999  Hazrat Shahjalal International Airport, Dhaka         RJH
#
#                                         Destination Name  \
# 56995  Netaji Subhas Chandra Bose International Airpo...
# 56996  Netaji Subhas Chandra Bose International Airpo...
# 56997                                    Jessore Airport
# 56998              Toronto Pearson International Airport
# ...

# %%
flight_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57000 entries, 0 to 56999
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Airline                57000 non-null  object
#  1   Source                 57000 non-null  object
#  2   Source Name            57000 non-null  object
#  3   Destination            57000 non-null  object
#  4   Destination Name       57000 non-null  object
#  5   Departure Date & Time  57000 non-null  object
#  6   Arrival Date & Time    57000 non-null  object
#  7   Duration (hrs)         57000 non-null  float64
#  8   Stopovers              57000 non-null  object
#  9   Aircraft Type          57000 non-null  object
#  10  Class                  57000 non-null  object
#  11  Booking Source         57000 non-null  object
#  12  Base Fare (BDT)        57000 non-null  float64
#  13  Tax & Surcharge (BDT)  57000 non-null  float64
# ...

# %%
flight_df.drop("Source", axis = 1, inplace = True)

# %%
flight_df.head()
# Out:
#               Airline                           Source Name Destination  \
# 0  Malaysian Airlines                   Cox's Bazar Airport         CCU
# 1      Cathay Pacific                       Barisal Airport         CGP
# 2     British Airways  Osmani International Airport, Sylhet         KUL
# 3  Singapore Airlines        Shah Makhdum Airport, Rajshahi         DAC
# 4     British Airways                       Saidpur Airport         YYZ
#
#                                     Destination Name Departure Date & Time  \
# 0  Netaji Subhas Chandra Bose International Airpo...       17/11/2025 6:25
# 1      Shah Amanat International Airport, Chittagong       16/03/2025 0:17
# 2                 Kuala Lumpur International Airport      13/12/2025 12:03
# 3      Hazrat Shahjalal International Airport, Dhaka       30/05/2025 3:21
# 4              Toronto Pearson International Airport       25/04/2025 9:14
#
#   Arrival Date & Time  Duration (hrs) Stopovers Aircraft Type        Class  \
# ...

# %%
flight_df.drop("Destination", axis = 1, inplace = True)

# %%
flight_df.head()
# Out:
#               Airline                           Source Name  \
# 0  Malaysian Airlines                   Cox's Bazar Airport
# 1      Cathay Pacific                       Barisal Airport
# 2     British Airways  Osmani International Airport, Sylhet
# 3  Singapore Airlines        Shah Makhdum Airport, Rajshahi
# 4     British Airways                       Saidpur Airport
#
#                                     Destination Name Departure Date & Time  \
# 0  Netaji Subhas Chandra Bose International Airpo...       17/11/2025 6:25
# 1      Shah Amanat International Airport, Chittagong       16/03/2025 0:17
# 2                 Kuala Lumpur International Airport      13/12/2025 12:03
# 3      Hazrat Shahjalal International Airport, Dhaka       30/05/2025 3:21
# 4              Toronto Pearson International Airport       25/04/2025 9:14
#
#   Arrival Date & Time  Duration (hrs) Stopovers Aircraft Type        Class  \
# ...

# %%
flight_df.rename(columns={"Source Name": "Source", "Destination Name" : "Destination"}, inplace  = True)

# %%
flight_df.head()
# Out:
#               Airline                                Source  \
# 0  Malaysian Airlines                   Cox's Bazar Airport
# 1      Cathay Pacific                       Barisal Airport
# 2     British Airways  Osmani International Airport, Sylhet
# 3  Singapore Airlines        Shah Makhdum Airport, Rajshahi
# 4     British Airways                       Saidpur Airport
#
#                                          Destination Departure Date & Time  \
# 0  Netaji Subhas Chandra Bose International Airpo...       17/11/2025 6:25
# 1      Shah Amanat International Airport, Chittagong       16/03/2025 0:17
# 2                 Kuala Lumpur International Airport      13/12/2025 12:03
# 3      Hazrat Shahjalal International Airport, Dhaka       30/05/2025 3:21
# 4              Toronto Pearson International Airport       25/04/2025 9:14
#
#   Arrival Date & Time  Duration (hrs) Stopovers Aircraft Type        Class  \
# ...

# %%
flight_df['Duration (hrs)'] = flight_df['Duration (hrs)'].round(0).astype(int)

# %%
flight_df.head(10)
# Out:
#               Airline                                         Source  \
# 0  Malaysian Airlines                            Cox's Bazar Airport
# 1      Cathay Pacific                                Barisal Airport
# 2     British Airways           Osmani International Airport, Sylhet
# 3  Singapore Airlines                 Shah Makhdum Airport, Rajshahi
# 4     British Airways                                Saidpur Airport
# 5              IndiGo           Osmani International Airport, Sylhet
# 6  US-Bangla Airlines                                Saidpur Airport
# 7             AirAsia                                Jessore Airport
# 8      Etihad Airways                                Saidpur Airport
# 9  US-Bangla Airlines  Hazrat Shahjalal International Airport, Dhaka
#
#                                          Destination Departure Date & Time  \
# 0  Netaji Subhas Chandra Bose International Airpo...       17/11/2025 6:25
# ...

# %%
flight_df['Base Fare (BDT)'] = flight_df['Base Fare (BDT)'].round(0).astype(int)
flight_df['Tax & Surcharge (BDT)'] = flight_df['Tax & Surcharge (BDT)'].round(0).astype(int)
flight_df['Total Fare (BDT)'] = flight_df['Total Fare (BDT)'].round(0).astype(int)

# %%
flight_df.head()
# Out:
#               Airline                                Source  \
# 0  Malaysian Airlines                   Cox's Bazar Airport
# 1      Cathay Pacific                       Barisal Airport
# 2     British Airways  Osmani International Airport, Sylhet
# 3  Singapore Airlines        Shah Makhdum Airport, Rajshahi
# 4     British Airways                       Saidpur Airport
#
#                                          Destination Departure Date & Time  \
# 0  Netaji Subhas Chandra Bose International Airpo...       17/11/2025 6:25
# 1      Shah Amanat International Airport, Chittagong       16/03/2025 0:17
# 2                 Kuala Lumpur International Airport      13/12/2025 12:03
# 3      Hazrat Shahjalal International Airport, Dhaka       30/05/2025 3:21
# 4              Toronto Pearson International Airport       25/04/2025 9:14
#
#   Arrival Date & Time  Duration (hrs) Stopovers Aircraft Type        Class  \
# ...

# %%
flight_df["Destination"].unique()
# Out:
# array(['Netaji Subhas Chandra Bose International Airport, Kolkata',
#        'Shah Amanat International Airport, Chittagong',
#        'Kuala Lumpur International Airport',
#        'Hazrat Shahjalal International Airport, Dhaka',
#        'Toronto Pearson International Airport', 'Saidpur Airport',
#        'Barisal Airport', 'London Heathrow Airport',
#        'Indira Gandhi International Airport, Delhi',
#        'Osmani International Airport, Sylhet',
#        'Shah Makhdum Airport, Rajshahi', 'Jessore Airport',
#        "Cox's Bazar Airport", 'Istanbul Airport',
#        'Dubai International Airport', 'Singapore Changi Airport',
#        'Suvarnabhumi Airport, Bangkok',
#        'Hamad International Airport, Doha',
#        'John F. Kennedy International Airport, New York',
#        'King Abdulaziz International Airport, Jeddah'], dtype=object)

# %%
flight_df.drop(["Base Fare (BDT)", "Tax & Surcharge (BDT)"], axis = 1 , inplace = True)

# %%
flight_df.head()
# Out:
#               Airline                                Source  \
# 0  Malaysian Airlines                   Cox's Bazar Airport
# 1      Cathay Pacific                       Barisal Airport
# 2     British Airways  Osmani International Airport, Sylhet
# 3  Singapore Airlines        Shah Makhdum Airport, Rajshahi
# 4     British Airways                       Saidpur Airport
#
#                                          Destination Departure Date & Time  \
# 0  Netaji Subhas Chandra Bose International Airpo...       17/11/2025 6:25
# 1      Shah Amanat International Airport, Chittagong       16/03/2025 0:17
# 2                 Kuala Lumpur International Airport      13/12/2025 12:03
# 3      Hazrat Shahjalal International Airport, Dhaka       30/05/2025 3:21
# 4              Toronto Pearson International Airport       25/04/2025 9:14
#
#   Arrival Date & Time  Duration (hrs) Stopovers Aircraft Type        Class  \
# ...

# %%
flight_df["Stopovers"].unique()
# Out:
# array(['Direct', '1 Stop', '2 Stops'], dtype=object)

# %%
flight_df["Booking Source"].unique()
# Out:
# array(['Online Website', 'Travel Agency', 'Direct Booking'], dtype=object)

# %%
flight_df["Seasonality"].unique()
# Out:
# array(['Regular', 'Winter Holidays', 'Eid', 'Hajj'], dtype=object)

# %%
flight_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57000 entries, 0 to 56999
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Airline                57000 non-null  object
#  1   Source                 57000 non-null  object
#  2   Destination            57000 non-null  object
#  3   Departure Date & Time  57000 non-null  object
#  4   Arrival Date & Time    57000 non-null  object
#  5   Duration (hrs)         57000 non-null  int32
#  6   Stopovers              57000 non-null  object
#  7   Aircraft Type          57000 non-null  object
#  8   Class                  57000 non-null  object
#  9   Booking Source         57000 non-null  object
#  10  Total Fare (BDT)       57000 non-null  int32
#  11  Seasonality            57000 non-null  object
#  12  Days Before Departure  57000 non-null  int64
# dtypes: int32(2), int64(1), object(10)
# memory usage: 5.2+ MB

# %%
flight_df["Airline"].unique()
# Out:
# array(['Malaysian Airlines', 'Cathay Pacific', 'British Airways',
#        'Singapore Airlines', 'IndiGo', 'US-Bangla Airlines', 'AirAsia',
#        'Etihad Airways', 'Gulf Air', 'Emirates',
#        'Biman Bangladesh Airlines', 'NovoAir', 'FlyDubai', 'Saudia',
#        'Thai Airways', 'Kuwait Airways', 'Air India', 'Air Astra',
#        'Qatar Airways', 'Air Arabia', 'SriLankan Airlines', 'Vistara',
#        'Lufthansa', 'Turkish Airlines'], dtype=object)

# %%
flight_df.shape
# Out:
# (57000, 13)
